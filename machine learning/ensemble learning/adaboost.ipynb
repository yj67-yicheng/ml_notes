# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

df = pd.read_csv('../data/wine0501.csv')
# df.info()

df = df[df['Class label'] != 1]
x = df[['Alcohol', 'Hue']]
y = df['Class label']

le = LabelEncoder()
y = le.fit_transform(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23, stratify=y)

estimator1 = DecisionTreeClassifier(max_depth=3, random_state=23)
estimator1.fit(x_train, y_train)
print(f'Single Decision Tree Classifier Score: {estimator1.score(x_test, y_test)}')

estimator2 = AdaBoostClassifier(estimator=estimator1, n_estimators=200, learning_rate=0.1, random_state=23)
estimator2.fit(x_train, y_train)
print(f'AdaBoost Classifier Score: {estimator2.score(x_test, y_test)}')
# Out:
# Single Decision Tree Classifier Score: 0.9166666666666666
# AdaBoost Classifier Score: 0.9583333333333334
