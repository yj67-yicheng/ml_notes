# %% [markdown]
# 一般用作（二）分类任务
#
# 把（线性回归处理后的）值 -> 通过sigmoid激活函数 映射到 [0, 1] -> 结合阈值，划分 正负样本
#
# loss function: 对数似然损失（negative log-likelihood loss, NLL Loss）
#     真实类别所在的位置，概率值越大越好
#
# LogisticRegression，默认将类别数量少的当做正例

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = pd.read_csv('../data/breast-cancer-wisconsin.csv')
# data.info()

data.replace('?', np.nan, inplace=True)
data.dropna(axis=0, inplace=True)  # axis=0 indicates rows
# data.info()

x = data.iloc[:, 1:-1]
y = data.iloc[:, -1]

print(x[:5])
print(y[:5])
print(x.shape, y.shape)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

estimator = LogisticRegression()
estimator.fit(x_train, y_train)
y_pred = estimator.predict(x_test)

# print(f'y pred: {y_pred}')

print(f'acc: {accuracy_score(y_test, y_pred)}')
# Out:
#    Clump Thickness  Uniformity of Cell Size  ...  Normal Nucleoli  Mitoses
# 0                5                        1  ...                1        1
# 1                5                        4  ...                2        1
# 2                3                        1  ...                1        1
# 3                6                        8  ...                7        1
# 4                4                        1  ...                1        1
#
# [5 rows x 9 columns]
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Class, dtype: int64
# (683, 9) (683,)
# acc: 0.9781021897810219
